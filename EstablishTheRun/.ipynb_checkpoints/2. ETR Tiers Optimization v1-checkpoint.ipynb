# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import shutil
import difflib
import openpyxl

today = date.today()
today = today.strftime("%m.%d.20%y")
today
# Out:
# '01.06.2022'

# %%
## ETR Daily

# changes the working directory to your downloads folder
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data'
daily_file = "DK NBA Projections.csv"

shutil.move(downloads + "/"+ daily_file,
           data_loc + "/"+ daily_file)

os.chdir(data_loc)

df = pd.read_csv(daily_file)

df.to_excel("ETR_Daily_"+str(today)+".xlsx", index=False)
os.remove("DK NBA Projections.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     562     try:
# --> 563         os.rename(src, real_dst)
#     564     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/vchang/Downloads/DK NBA Projections.csv' -> 'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data/DK NBA Projections.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-a459edd3c15a> in <module>
#       9
#      10 shutil.move(downloads + "/"+ daily_file,
# ---> 11            data_loc + "/"+ daily_file)
#      12
#      13 os.chdir(data_loc)
#
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     575             rmtree(src)
#     576         else:
# --> 577             copy_function(src, real_dst)
#     578             os.unlink(src)
#     579     return real_dst
#
# ~\Anaconda3\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# ~\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/vchang/Downloads/DK NBA Projections.csv'

# %%
## DKNG Tiers

contest = "Tiers_"
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
contest_data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/Tiers'

shutil.move(downloads + "/"+ "DKSalaries.csv",
           contest_data_loc + "/"+ "DKSalaries.csv")

os.chdir(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/Tiers")
dkng_file = shutil.copy("DKSalaries.csv", "DKSalaries_"+ contest + str(today)+".csv")
os.remove("DKSalaries.csv")

# %%
## Merge

os.chdir(r"C:\Users\vchang\Documents\Fantasy Bball\DFS\Tiers Analysis")
etr = pd.read_excel(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\ETR_Data\ETR_Daily_' + str(today) + ".xlsx")
dkng = pd.read_csv(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\DKNG_Data\Tiers\DKSalaries_Tiers_' + str(today) + ".csv")


final = pd.merge(etr,
                 dkng[['Name','Roster Position']], 
                 left_on = 'Player',
                 right_on='Name',
                 how='left')

final.dropna(subset=['Roster Position'], inplace=True)

final = final.sort_values(by='DK Points', ascending = False)

final.to_excel("ETR_final_Tiers_"+str(today)+".xlsx", index=False)
os.system("ETR_final_Tiers_"+str(today)+".xlsx")
# Out:
# 0

# %%
df = final.dropna(subset=['Roster Position'])
df.head()
df1 = df.loc[df.groupby('Roster Position')['DK Points'].idxmax()]
df1
# Out:
#                Player Team  Opp  Minutes DK Position DK Salary  DK Points  \
# 2           Ja Morant  MEM  DET     34.0          PG     9,200       47.5
# 7        Devin Booker  PHX  LAC     35.0       PG/SG     8,700       43.4
# 0        Jordan Poole  GSW  NOP     35.0          SG     5,800       40.8
# 22  Jonas Valanciunas  NOP  GSW     31.0           C     8,800       40.6
# 4      Reggie Jackson  LAC  PHX     32.0          PG     6,100       34.1
#
#     DK Value  DK Ceiling  DK Own DK Slate               Name Roster Position
# 2        4.7        56.3    30.6     MAIN          Ja Morant              T1
# 7        2.6        51.6    45.0     MAIN       Devin Booker              T3
# 0       11.6        49.0    54.6     MAIN       Jordan Poole              T6
# 22      -0.6        48.3     9.0     MAIN  Jonas Valanciunas              T2
# 4        3.7        42.0    20.0     MAIN     Reggie Jackson              T5
