# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
import shutil
import openpyxl

today = date.today()
today = today.strftime("%m.%d.20%y")
today
# Out:
# '12.31.2021'

# %%
## ETR Daily

# changes the working directory to your downloads folder
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data'
daily_file = "DK NBA Projections.csv"

shutil.move(downloads + "/"+ daily_file,
           data_loc + "/"+ daily_file)

os.chdir(data_loc)

df = pd.read_csv(daily_file)

df.to_excel("ETR_Daily_"+str(today)+".xls", index=False)
os.remove("DK NBA Projections.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     562     try:
# --> 563         os.rename(src, real_dst)
#     564     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/vchang/Downloads/DK NBA Projections.csv' -> 'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data/DK NBA Projections.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6fd58c99b872> in <module>
#       9
#      10 shutil.move(downloads + "/"+ daily_file,
# ---> 11            data_loc + "/"+ daily_file)
#      12
#      13 os.chdir(data_loc)
#
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     575             rmtree(src)
#     576         else:
# --> 577             copy_function(src, real_dst)
#     578             os.unlink(src)
#     579     return real_dst
#
# ~\Anaconda3\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# ~\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/vchang/Downloads/DK NBA Projections.csv'

# %%
## DKNG Player Pool

contest = "PlayerPool_"
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
contest_data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool'

shutil.move(downloads + "/"+ "DKSalaries.csv",
           contest_data_loc + "/"+ "DKSalaries.csv")

os.chdir(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool")
dkng_file = shutil.copy("DKSalaries.csv", "DKSalaries_"+ contest + str(today)+".csv")
dkng_file = pd.read_csv(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool/DKSalaries.csv")
dkng_file.to_excel(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool/DKSalaries_"+ contest + str(today)+".xlsx", index=False)
os.remove("DKSalaries.csv")
os.remove("DKSalaries_"+ contest + str(today)+".csv")

# %%
os.chdir(r"C:\Users\vchang\Documents\Fantasy Bball\DFS\ETR_Data")
df = pd.read_excel("ETR_Daily_" + str(today) + ".xls")

# %%
df.head()
df['DK Position'] = df['DK Position'].str.split('/')
explode = df.explode('DK Position')
explode.head()
# Out:
#         Player Team  Opp  Minutes DK Position DK Salary  DK Points  DK Value  \
# 0  Tyler Herro  MIA  HOU     39.0          PG     7,200       43.2       8.4
# 0  Tyler Herro  MIA  HOU     39.0          SG     7,200       43.2       8.4
# 1  Serge Ibaka  LAC  TOR     27.0          PF     3,200       27.2       8.4
# 1  Serge Ibaka  LAC  TOR     27.0           C     3,200       27.2       8.4
# 2     Naz Reid  MIN  UTA     31.0          PF     5,100       33.6       7.2
#
#    DK Ceiling  DK Own DK Slate
# 0        50.9       0     MAIN
# 0        50.9       0     MAIN
# 1        34.3       0     MAIN
# 1        34.3       0     MAIN
# 2        40.7       0     MAIN
