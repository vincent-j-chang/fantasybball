# %%
#import packages and create date

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import *
import shutil
import difflib
from pulp import *
import openpyxl
import glob

import datetime
today = date.today()
#today = today - datetime.timedelta(days=1)
today = today.strftime("%m.%d.20%y")
today

time = "9pm_"

# %%
## DKNG Player Pool

contest = "PlayerPool_"
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
contest_data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool'

df = pd.read_csv(r'C:/Users/vchang/Downloads/DKEntries.csv', header=7, usecols=[13,15,16,17,18,19,20,21])
df.to_csv("DKSalaries_"+ contest + time + str(today) +".csv", index=False)

shutil.move(downloads + "/"+ "DKSalaries_"+ contest + time + str(today) +".csv",
           contest_data_loc + "/"+ "DKSalaries_"+ contest + time + str(today) +".csv")

os.chdir(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool")
# dkng_file = shutil.copy("DKSalaries.csv", "DKSalaries_"+ contest + time + str(today) +".csv")
dkng_file = pd.read_csv(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool/DKSalaries_"+ contest + time + str(today) +".csv")
dkng_file.to_excel(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool/DKSalaries_"+ contest + time + str(today) +".xlsx", index=False)

os.chdir(r"C:/Users/vchang/Documents/Fantasy Bball/DFS/DKNG_Data/PlayerPool")
os.remove("DKSalaries_"+ contest + time + str(today) +".csv")


## Uploads
## Uploads
os.chdir(r"C:\Users\vchang\Downloads")

draftkings_upload = r"C:\Users\vchang\Documents\Fantasy Bball\DFS\Upload\DraftKings\Template"

dk_upload = glob.glob('DKEntries.csv')[0]
os.rename(dk_upload, "DK_Upload_"+ contest + time + str(today) +".csv")

shutil.move(downloads + "/"+ "DK_Upload_"+ contest + time + str(today) +".csv",
           draftkings_upload + "/"+ "DK_Upload_"+ contest + time + str(today) +".csv")
# Out:
# 'C:\\Users\\vchang\\Documents\\Fantasy Bball\\DFS\\Upload\\DraftKings\\Template/DK_Upload_PlayerPool_730pm_03.30.2022.csv'

# %%
## ETR Daily

# changes the working directory to your downloads folder
os.chdir(r"C:\Users\vchang\Downloads")

downloads = r'C:/Users/vchang/Downloads'
data_loc = r'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data/DraftKings'
daily_file = "DK NBA Projections.csv"

shutil.move(downloads + "/"+ daily_file,
           data_loc + "/"+ daily_file)

os.chdir(data_loc)

df = pd.read_csv(daily_file)

df.to_excel("ETR_Daily_"+ time + str(today)+".xlsx", index=False)
os.remove("DK NBA Projections.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     562     try:
# --> 563         os.rename(src, real_dst)
#     564     except OSError:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:/Users/vchang/Downloads/DK NBA Projections.csv' -> 'C:/Users/vchang/Documents/Fantasy Bball/DFS/ETR_Data/DraftKings/DK NBA Projections.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-00b55cc2810d> in <module>
#       9
#      10 shutil.move(downloads + "/"+ daily_file,
# ---> 11            data_loc + "/"+ daily_file)
#      12
#      13 os.chdir(data_loc)
#
# ~\Anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     575             rmtree(src)
#     576         else:
# --> 577             copy_function(src, real_dst)
#     578             os.unlink(src)
#     579     return real_dst
#
# ~\Anaconda3\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     261     if os.path.isdir(dst):
#     262         dst = os.path.join(dst, os.path.basename(src))
# --> 263     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     264     copystat(src, dst, follow_symlinks=follow_symlinks)
#     265     return dst
#
# ~\Anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     118         os.symlink(os.readlink(src), dst)
#     119     else:
# --> 120         with open(src, 'rb') as fsrc:
#     121             with open(dst, 'wb') as fdst:
#     122                 copyfileobj(fsrc, fdst)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/vchang/Downloads/DK NBA Projections.csv'

# %%
## Joins the DKNG and ETR Files to include DKNG Positions 
    ## ETR does not include G/F/UTIL

os.chdir(r"C:\Users\vchang\Documents\Fantasy Bball\DFS\PlayerPool Analysis")
etr = pd.read_excel(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\ETR_Data\DraftKings\ETR_Daily_' + time + str(today)  + ".xlsx")
dkng = pd.read_excel(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\DKNG_Data\PlayerPool\DKSalaries_PlayerPool_' + time + str(today)  + ".xlsx")


dkng['ID'] = dkng['ID'].astype(str)
dkng['Name + ID'] = dkng['Name'] + ' (' + dkng['ID'] + ')'

df = pd.merge(etr, 
              dkng[['Name','Roster Position', 'Name + ID', 'Salary']], 
              left_on='Player', 
              right_on='Name')



## Unnests Roster Positions into each Row (explode in Python) ##

# Update Salary to INT 
df['DK Salary'] = df['DK Salary'].str.replace(",","").astype(float)

# Update Roster Position to Str
df['Roster Position'] = df['Roster Position'].astype(str)

# Delimit the text by /
df['Roster Position'] = df['Roster Position'].str.split('/')

df = df.explode('Roster Position')

df.head()

df.to_csv("DKNG_final_PlayerPool_ETR_"+ time + str(today) +".csv", index=False)
# os.system("DKNG_final_PlayerPool_ETR_"+ time + str(today) +".xlsx")

# %%
## Optimizer

df = pd.read_csv("DKNG_final_PlayerPool_ETR_"+ time + str(today) +".csv", index_col=['Name + ID', 'Roster Position'], skipinitialspace=True)

legal_assignments = df.index # tuples of (name, pos)
name_set = df.index.unique(0) # a convenience

costs = df['Salary'].to_dict()
values = df['DK Ceiling'].to_dict()

# set up LP
draft = pulp.LpVariable.dicts('selected', legal_assignments, cat='Binary')

prob = pulp.LpProblem('the draft', LpMaximize)

#obj
prob += pulp.lpSum([draft[n,p]*values[n,p] for (n,p) in legal_assignments])

#salary cap
prob += pulp.lpSum([draft[n,p]*costs[n,p] for (n, p) in legal_assignments]) <= 50000

# positions
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'PG']) <= 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'SG']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'G']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'SF']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'PF']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'F']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'C']) == 1
prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if p == 'UTIL']) == 1

# use each player at most only once
result = []
for name in name_set:
    prob += pulp.lpSum([draft[n, p] for (n, p) in legal_assignments if n == name]) <= 1

prob.solve()

for idx in draft:
    if draft[idx].varValue > 0:
        print(idx[0], idx[1])
        
        result.append([idx[0], idx[1]])
# Out:
# Nikola Jokic (21920525) C
# Brandon Ingram (21920545) SF
# Patrick Beverley (21920592) G
# D'Angelo Russell (21920555) PG
# Bones Hyland (21920588) SG
# Jarred Vanderbilt (21920610) F
# Aaron Gordon (21920559) PF
# DeMarcus Cousins (21920635) UTIL
# C:\Users\vchang\Anaconda3\lib\site-packages\pulp\pulp.py:1313: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %%
# Change dataframe from column to row

new_list = result
df = pd.DataFrame(new_list)
test = df[[1,0]]
test1 = test.transpose()
test2 = test1.rename(columns=test1.iloc[0])
test3 = test2.drop([1])
df2 = test3[['PG', 'SG','SF', 'PF', 'C', 'G', 'F', 'UTIL']]
df2.to_csv("dkng_result_" + time + str(today)  + ".csv", index=None)
# os.system("dkng_result_" + time + str(today)  + ".csv")

# %%
df2 = pd.read_csv(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\PlayerPool Analysis\dkng_result_' + time + str(today)  + ".csv")

upload = pd.read_csv(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\Upload\DraftKings\Template\DK_Upload_PlayerPool_' + time + str(today)  + ".csv"
                      , #usecols=[0,1,2,3], 
                     error_bad_lines=False, engine ='python')
upload = upload.dropna()
upload = upload[['Entry ID', 'Contest Name', 'Contest ID', 'Entry Fee']]

# Drops rows that have NaN
upload2 = upload.dropna()
# creates value for row counts in the upload file
repeat_rows = len(upload2.index)

# duplicates lineups down rows based on number of contests (length of rows)
# copies columns from old data frame onto new dataframe
df3 = pd.DataFrame(np.repeat(df2.values, repeat_rows, axis=0))
df3.columns = df2.columns

# joins the two data frames
os.chdir(r'C:\Users\vchang\Documents\Fantasy Bball\DFS\Upload\DraftKings\FinalUpload')
result = pd.concat([upload2, df3], axis=1)

# saves the dataframe
result.to_csv("DK_Final_Upload_Ceiling_" + time + str(today) +".csv", index=False)
os.system("DK_Final_Upload_Ceiling_"+ time + str(today) +".csv")
# Out:
# Skipping line 8: Expected 14 fields in line 8, saw 22
# Skipping line 9: Expected 14 fields in line 9, saw 22
# Skipping line 10: Expected 14 fields in line 10, saw 22
# Skipping line 11: Expected 14 fields in line 11, saw 22
# Skipping line 12: Expected 14 fields in line 12, saw 22
# Skipping line 13: Expected 14 fields in line 13, saw 22
# Skipping line 14: Expected 14 fields in line 14, saw 22
# Skipping line 15: Expected 14 fields in line 15, saw 22
# Skipping line 16: Expected 14 fields in line 16, saw 22
# Skipping line 17: Expected 14 fields in line 17, saw 22
# Skipping line 18: Expected 14 fields in line 18, saw 22
# Skipping line 19: Expected 14 fields in line 19, saw 22
# Skipping line 20: Expected 14 fields in line 20, saw 22
# Skipping line 21: Expected 14 fields in line 21, saw 22
# Skipping line 22: Expected 14 fields in line 22, saw 22
# Skipping line 23: Expected 14 fields in line 23, saw 22
# Skipping line 24: Expected 14 fields in line 24, saw 22
# Skipping line 25: Expected 14 fields in line 25, saw 22
# Skipping line 26: Expected 14 fields in line 26, saw 22
# Skipping line 27: Expected 14 fields in line 27, saw 22
# Skipping line 28: Expected 14 fields in line 28, saw 22
# Skipping line 29: Expected 14 fields in line 29, saw 22
# Skipping line 30: Expected 14 fields in line 30, saw 22
# Skipping line 31: Expected 14 fields in line 31, saw 22
# Skipping line 32: Expected 14 fields in line 32, saw 22
# Skipping line 33: Expected 14 fields in line 33, saw 22
# Skipping line 34: Expected 14 fields in line 34, saw 22
# Skipping line 35: Expected 14 fields in line 35, saw 22
# Skipping line 36: Expected 14 fields in line 36, saw 22
# Skipping line 37: Expected 14 fields in line 37, saw 22
# Skipping line 38: Expected 14 fields in line 38, saw 22
# Skipping line 39: Expected 14 fields in line 39, saw 22
# Skipping line 40: Expected 14 fields in line 40, saw 22
# Skipping line 41: Expected 14 fields in line 41, saw 22
# Skipping line 42: Expected 14 fields in line 42, saw 22
# Skipping line 43: Expected 14 fields in line 43, saw 22
# Skipping line 44: Expected 14 fields in line 44, saw 22
# Skipping line 45: Expected 14 fields in line 45, saw 22
# Skipping line 46: Expected 14 fields in line 46, saw 22
# Skipping line 47: Expected 14 fields in line 47, saw 22
# Skipping line 48: Expected 14 fields in line 48, saw 22
# Skipping line 49: Expected 14 fields in line 49, saw 22
# Skipping line 50: Expected 14 fields in line 50, saw 22
# Skipping line 51: Expected 14 fields in line 51, saw 22
# Skipping line 52: Expected 14 fields in line 52, saw 22
# Skipping line 53: Expected 14 fields in line 53, saw 22
# Skipping line 54: Expected 14 fields in line 54, saw 22
# Skipping line 55: Expected 14 fields in line 55, saw 22
# Skipping line 56: Expected 14 fields in line 56, saw 22
# Skipping line 57: Expected 14 fields in line 57, saw 22
# Skipping line 58: Expected 14 fields in line 58, saw 22
# Skipping line 59: Expected 14 fields in line 59, saw 22
# Skipping line 60: Expected 14 fields in line 60, saw 22
# Skipping line 61: Expected 14 fields in line 61, saw 22
# Skipping line 62: Expected 14 fields in line 62, saw 22
# Skipping line 63: Expected 14 fields in line 63, saw 22
# Skipping line 64: Expected 14 fields in line 64, saw 22
# Skipping line 65: Expected 14 fields in line 65, saw 22
# Skipping line 66: Expected 14 fields in line 66, saw 22
# Skipping line 67: Expected 14 fields in line 67, saw 22
# Skipping line 68: Expected 14 fields in line 68, saw 22
# Skipping line 69: Expected 14 fields in line 69, saw 22
# Skipping line 70: Expected 14 fields in line 70, saw 22
# Skipping line 71: Expected 14 fields in line 71, saw 22
# Skipping line 72: Expected 14 fields in line 72, saw 22
# Skipping line 73: Expected 14 fields in line 73, saw 22
# Skipping line 74: Expected 14 fields in line 74, saw 22
# Skipping line 75: Expected 14 fields in line 75, saw 22
# Skipping line 76: Expected 14 fields in line 76, saw 22
# Skipping line 77: Expected 14 fields in line 77, saw 22
# Skipping line 78: Expected 14 fields in line 78, saw 22
# Skipping line 79: Expected 14 fields in line 79, saw 22
# Skipping line 80: Expected 14 fields in line 80, saw 22
# Skipping line 81: Expected 14 fields in line 81, saw 22
# Skipping line 82: Expected 14 fields in line 82, saw 22
# Skipping line 83: Expected 14 fields in line 83, saw 22
# Skipping line 84: Expected 14 fields in line 84, saw 22
# Skipping line 85: Expected 14 fields in line 85, saw 22
# Skipping line 86: Expected 14 fields in line 86, saw 22
# Skipping line 87: Expected 14 fields in line 87, saw 22
# Skipping line 88: Expected 14 fields in line 88, saw 22
# Skipping line 89: Expected 14 fields in line 89, saw 22
# Skipping line 90: Expected 14 fields in line 90, saw 22
# Skipping line 91: Expected 14 fields in line 91, saw 22
# Skipping line 92: Expected 14 fields in line 92, saw 22
# Skipping line 93: Expected 14 fields in line 93, saw 22
# Skipping line 94: Expected 14 fields in line 94, saw 22
# Skipping line 95: Expected 14 fields in line 95, saw 22
# Skipping line 96: Expected 14 fields in line 96, saw 22
# Skipping line 97: Expected 14 fields in line 97, saw 22
# Skipping line 98: Expected 14 fields in line 98, saw 22
# Skipping line 99: Expected 14 fields in line 99, saw 22
# Skipping line 100: Expected 14 fields in line 100, saw 22
# 0
